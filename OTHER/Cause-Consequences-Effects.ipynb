# %%
with open('TRAIN_FILE.TXT') as f:
    train_file = f.readlines()

# %%
train_file
# Out:
# ['1\t"The system as described above has its greatest application in an arrayed <e1>configuration</e1> of antenna <e2>elements</e2>."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment: Not a collection: there is structure here, organisation.\n',
#  '\n',
#  '2\t"The <e1>child</e1> was carefully wrapped and bound into the <e2>cradle</e2> by means of a cord."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '3\t"The <e1>author</e1> of a keygen uses a <e2>disassembler</e2> to look at the raw assembly code."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '4\t"A misty <e1>ridge</e1> uprises from the <e2>surge</e2>."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '5\t"The <e1>student</e1> <e2>association</e2> is the voice of the undergraduate student population of the State University of New York at Buffalo."\n',
#  'Member-Collection(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '6\t"This is the sprawling <e1>complex</e1> that is Peru\'s largest <e2>producer</e2> of silver."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '7\t"The current view is that the chronic <e1>inflammation</e1> in the distal part of the stomach caused by Helicobacter pylori <e2>infection</e2> results in an increased acid production from the non-infected upper corpus region of the stomach."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '8\t"<e1>People</e1> have been moving back into <e2>downtown</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '9\t"The <e1>lawsonite</e1> was contained in a <e2>platinum crucible</e2> and the counter-weight was a plastic crucible with metal pieces."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '10\t"The solute was placed inside a beaker and 5 mL of the <e1>solvent</e1> was pipetted into a 25 mL glass <e2>flask</e2> for each trial."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '11\t"The fifty <e1>essays</e1> collected in this <e2>volume</e2> testify to most of the prominent themes from Professor Quispel\'s scholarly career."\n',
#  'Member-Collection(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '12\t"Their <e1>composer</e1> has sunk into <e2>oblivion</e2>."\n',
#  'Other\n',
#  'Comment: violates b.1 and c.3\n',
#  '\n',
#  '13\t"The Pulitzer Committee issues an official <e1>citation</e1> explaining the <e2>reasons</e2> for the award."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '14\t"The <e1>burst</e1> has been caused by water hammer <e2>pressure</e2>."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '15\t"Even commercial <e1>networks</e1> have moved into <e2>high-definition broadcast</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '16\t"It was a friendly <e1>call</e1> to remind them about the <e2>bill</e2> and make sure they have a copy of the invoice."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '17\t"Texas-born <e1>virtuoso</e1> finds harmony, sophistication in Appalachian <e2>instrument</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '18\t"The <e1>factory</e1>\'s products have included flower pots, Finnish rooster-whistles, pans, <e2>trays</e2>, tea pots, ash trays and air moisturisers."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '19\t"The girl showed a photo of apple <e1>tree</e1> <e2>blossom</e2> on a fruit tree in the Central Valley."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '20\t"They tried an assault of their own an hour later, with two columns of sixteen tanks backed by a <e1>battalion</e1> of Panzer <e2>grenadiers</e2>."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '21\t"Their <e1>knowledge</e1> of the power and rank symbols of the Continental empires was gained from the numerous Germanic <e2>recruits</e2> in the Roman army, and from the Roman practice of enfeoffing various Germanic warrior groups with land in the imperial provinces."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '22\t"She soon had a <e1>stable</e1> of her own rescued <e2>hounds</e2>."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '23\t"The <e1>singer</e1>, who performed three of the nominated songs, also caused a <e2>commotion</e2> on the red carpet."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '24\t"His intellectually engaging books and <e1>essays</e1> remain pertinent to illuminating contemporary <e2>history</e2>."\n',
#  'Other\n',
#  'Comment: "pertinent to" is not necessarily about\n',
#  '\n',
#  '25\t"Poor hygiene controls, reports of a <e1>brace</e1> of gamey <e2>grouse</e2> and what looked like a skinned fox all amounted to a pie that was unfit for human consumption."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment: modality is outside\n',
#  '\n',
#  '26\t"This sweet <e1>dress</e1> is made with a <e2>blend</e2> of cotton and silk, and the crochet flower necklace is the perfect accessory."\n',
#  'Other\n',
#  "Comment: the blend is the material out of which the dress is made; can't be Entity-Origin because the material is still present in the dress\n",
#  '\n',
#  '27\t"<e1>Suicide</e1> is one of the leading causes of <e2>death</e2> among pre-adolescents and teens, and victims of bullying are at an increased risk for committing suicide."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '28\t"This <e1>article</e1> gives details on 2004 in <e2>music</e2> in the United Kingdom, including the official charts from that year."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '29\t"We have therefore taken the initiative to convene the first international open <e1>meeting</e1> dedicated solely to <e2>rural history</e2>."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '30\t"The <e1>timer</e1> of the <e2>device</e2> automatically eliminates wasted "standby power" consumption by automatically turn off electronics plugged into the "auto off" outlets."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment: "by turn off" should be "by turning off", error is in the source text.\n',
#  '\n',
#  '31\t"Bob Parks made a similar <e1>offer</e1> in a <e2>phone call</e2> made earlier this week."\n',
#  'Message-Topic(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '32\t"He had chest pains and <e1>headaches</e1> from <e2>mold</e2> in the bedrooms."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '33\t"The silver-haired author was not just laying India\'s politician saint to rest but healing a generations-old rift in the family of the <e1>country</e1>\'s founding <e2>father</e2>."\n',
#  'Product-Producer(e1,e2)\n',
#  'Comment: in an abstract way the country is built/founded/produced by the father\n',
#  '\n',
#  '34\t"It describes a method for loading a horizontal <e1>stack</e1> of containers into a <e2>carton</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment: the carton holds the containers\n',
#  '\n',
#  '35\t"The Foundation decided to repurpose the building in order to reduce wear and tear on the <e1>plumbing</e1> in the <e2>manor house</e2> by redirecting visitors during restoration projects and beyond."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '36\t"The technology is available to produce and transmit <e1>electricity</e1> economically from OTEC <e2>systems</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '37\t"The Medicare buy-in <e1>plan</e1> ran into Senate <e2>resistance</e2>."\n',
#  'Other\n',
#  'Comment: violates c.3\n',
#  '\n',
#  '38\t"The <e1>provinces</e1> are divided into <e2>counties</e2> (shahrestan), and subdivided into districts (bakhsh) and sub-districts (dehestan)."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '39\t"Financial <e1>stress</e1> is one of the main causes of <e2>divorce</e2>."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '40\t"<e1>Newspapers</e1> swap content via widgets with the help of the newsgator <e2>service</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '41\t"The <e1>women</e1> that caused the <e2>accident</e2> was on the cell phone and ran thru the intersection without pausing on the median."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '42\t"The <e1>transmitter</e1> was discovered inside a bed settee <e2>suite</e2> on which he had been sitting."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '43\t"The Kerala backwaters are a <e1>chain</e1> of brackish <e2>lagoons</e2> and lakes lying parallel to the Arabian Sea coast of Kerala state in southern India."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '44\t"A St. Paul College <e1>student</e1> was released from <e2>jail</e2> Wednesday night, after his arrest Tuesday in the alleged rape of another student on campus."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '45\t"<e1>Calluses</e1> are caused by improperly fitting shoes or by a <e2>skin abnormality</e2>."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '46\t"<e1>Adults</e1> use <e2>drugs</e2> for this purpose."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '47\t"The <e1>councilor</e1> proposed assessing infinitival complements through <e2>elicitation</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '48\t"As in the popular movie "Deep Impact", the action of the Perseid <e1>meteor shower</e1> is caused by a <e2>comet</e2>, in this case periodic comet Swift-Tuttle."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '49\t"The following information appeared in the <e1>notes</e1> to consolidated financial <e2>statements</e2> of some corporate annual reports."\n',
#  'Other\n',
#  'Comment: We do not know what the notes are talking about; we only know that the notes are somehow connected to the statement.\n',
#  '\n',
#  '50\t"HipHop appropriates the symbols of a consumer society: oversized <e1>diamond</e1> <e2>colliers</e2> are worn."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '51\t"The <e1>radiation</e1> from the atomic <e2>bomb explosion</e2> is a typical acute radiation."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '52\t"The ride-on <e1>boat</e1> <e2>tiller</e2> was developed by engineers Arnold S. Juliano and Dr. Eulito U. Bautista."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '53\t"A neoplastic <e1>recurrence</e1> arose from an extensive <e2>radiation</e2> induced ulceration."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '54\t"He has a tattoo on his right arm and <e1>scars</e1> from <e2>stitches</e2> on his right elbow."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '55\t"Whether your home includes a charm of finches, a sute of bloodhounds, or a <e1>knob</e1> of <e2>toads</e2>, I think it\'s important to keep the numbers within reason."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '56\t"Furthermore, these INGO practitioners constructed a <e1>discourse</e1> around <e2>participation</e2> which distorted the real significance of participation."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '57\t"Kelvin bought a <e1>silver</e1> <e2>ring</e2> which he was so happy with and he keeps wearing it now even though its abit too big haha."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '58\t"Scientists are in the midst of an ongoing <e1>debate</e1> about the relative <e2>value</e2> of openness and collaboration in their profession."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment: A debate is a multi-way message. (Debatable, I know.)\n',
#  '\n',
#  '59\t"This cut blue and white striped cotton <e1>dress</e1> with red bands on the bodice was in a <e2>trunk</e2> of vintage Barbie clothing."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '60\t"My major <e1>disagreement</e1> with Lyons concerns the <e2>causal part</e2> of his theory."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '61\t"Both his <e1>feet</e1> have been moving into the <e2>ball</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '62\t"The scissors were in a small plastic soap container, next to a bar of soap, and the <e1>box cutters</e1> were in a <e2>box</e2> next to a bottle of after-shave lotion."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '63\t"A great <e1>wing</e1> of fluorite <e2>dragons</e2>, the greatest concentration of the rather solitary dragons ever known, joined the desperate battle with the blues and silvers against Chaos."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '64\t"As a control, <e1>cowpea</e1> was sealed in <e2>double bags</e2> without fumigant."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '65\t"The infectious bacterial disease <e1>brucellosis</e1> has been found in a beef <e2>cow</e2> in eastern Idaho."\n',
#  'Other\n',
#  'Comment: diseases are not parts.\n',
#  '\n',
#  '66\t"As the Anglo-Norman force sustained but little loss in this battle, their archers at the onset showered a hail of arrows upon the Irish host who were not protected with mail armour, and shot them down in hundreds before they could get to close quarters; and then the charge of the heavy Anglo-Norman cavalry of mail-clad knights, completed the havoc and <e1>rout</e1> of the undisciplined Gaelic <e2>hosts</e2>."\n',
#  'Other\n',
#  'Comment: The pattern is at fault -- "rout" is not the name of a grouping; negation is outside\n',
#  '\n',
#  '67\t"The first incarnation of this series was set in the 1940s, during World War II, when the <e1>princess</e1> left her native paradise <e2>island</e2> (where Amazon women had lived for centuries) to help the U.S. foil the Nazis."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '68\t"Cieply\'s <e1>story</e1> makes a compelling <e2>point</e2> about modern-day studio economics."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '69\t"We poured the <e1>milk</e1> into the <e2>pumpkin mixture</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '70\t"Lawyers in Detroit also worked overtime as several <e1>lawsuits</e1> ensued from angry and injured <e2>fans</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '71\t"The continuing Nigerian <e1>outbreak</e1> is the biggest ever caused by the <e2>vaccine</e2>."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '72\t"Our mercenary Army has now degenerated into a Godless <e1>cabal</e1> of mindless <e2>killers</e2> not unlike the Soviets that were butchering civilians in Afghanistan (exactly as sadistically as we have)."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '73\t"The <e1>fire</e1> inside WTC was caused by exploding <e2>fuel</e2>."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '74\t"The <e1>epithelium</e1> from the knockout mouse bladder is migrating into the transplanted <e2>matrix</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '75\t"The <e1>staff</e1> was removed from his <e2>position</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '76\t"The <e1>suffering</e1> caused by the <e2>terrorists</e2> is the real torture."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '77\t"This <e1>love</e1> of nature\'s gift has been reflected in <e2>artworks</e2> dating back more than a thousand years."\n',
#  'Message-Topic(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '78\t"The <e1>court</e1> decided the objection by making the instalment <e2>order</e2> as sought."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '79\t"In a poetic twist, the <e1>tsunami</e1> triggered by the rock <e2>band</e2> forced many American jazz and blues singers to seek work in the United Kingdom, which is where Anderson found a receptive audience in 1965."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '80\t"<e1>Leakage</e1> and fire caused due to <e2>corrosion</e2> of bypass piping for recirculation gas at a fuel oil desulphurization unit."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '81\t"A team of students from Virginia Tech University have created a vehicle that allows vision impaired <e1>drivers</e1> to take control of the <e2>wheel</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '82\t"BMW\'s iDrive 4.0 brings in a <e1>horde</e1> of new <e2>features</e2>."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '83\t"The metal <e1>ball</e1> makes a ding ding ding <e2>noise</e2> when it swings back and hits the metal body of the lamp."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '84\t"It consists of an <e1>ensemble</e1> of <e2>ladies</e2> who are highly qualified to play various Arabic musical instruments."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '85\t"It underscores the need for continued surveillance of nicotine delivery in <e1>products</e1> created by an unregulated <e2>industry</e2>."\n',
#  'Product-Producer(e1,e2)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '86\t"Unlike other fish, grunion come out of the water completely to lay their eggs in the wet <e1>sand</e1> of the <e2>beach</e2>."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '87\t"A large <e1>marble</e1> was dropped into the <e2>bowl</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '88\t"Historical view of the <e1>damage</e1> caused by the 1693 Catania <e2>earthquake</e2> and the reconstruction activities."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '89\t"AI requested that the perpetrators be prosecuted to the fullest extent of the law, that adequate compensation be provided to the victims and that senior government and police officials offer apologies for the <e1>suffering</e1> caused by the responsible police <e2>officers</e2>."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '90\t"The <e1>findings</e1> have been published in a special <e2>section</e2> of the academic journal Archives of Sexual Behavior."\n',
#  'Other\n',
#  'Comment: Location. It cannot be Content-Container since the Content should be removable. It also cannot be Component-Whole since it violates (d).\n',
#  '\n',
#  '91\t"An Amtrak <e1>passenger</e1> who alarmed fellow passengers by talking about terrorist threats on a cellphone was pulled from the <e2>train</e2> and is being held in Colorado."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '92\t"The <e1>introduction</e1> in the <e2>book</e2> is a summary of what is in the text."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '93\t"The second <e1>simulation</e1> was started from the uncomplexed x-ray <e2>structure</e2> after insertion of the ligand into the binding site."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '94\t"This <e1>user</e1> plays games on a portable <e2>console</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '95\t"The ambitious Eurasia <e1>exhibition</e1> arose from an <e2>idea</e2> by Achille Bonito Oliva."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '96\t"The <e1>driver</e1> of the cement truck cleaned the loading chute on his truck with a truck-mounted water <e2>hose</e2> and began to pull away."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '97\t"The Marshall Plan also provided a way of gaining public acceptance in Europe for the New Deal format that the United States had successfully used before the war to end the <e1>recession</e1> triggered by the 1929 Wall Street <e2>crash</e2>."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '98\t"In the corner there are several gate captains and a <e1>legion</e1> of Wu <e2>crossbowmen</e2>."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '99\t"Once they grow there, the <e1>swelling</e1> and inflammation caused by the <e2>infection</e2> closes off the sac, causing it not to "shed" bacteria, and protecting the bacteria inside from antibiotics and your body\'s own immune cells."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '100\t"Guitars are played acoustically; the <e1>tone</e1> is produced by the <e2>vibration</e2> of the strings which is amplified by the body of the guitar, which acts as a large hollow resonating chamber, or they may rely on an amplifier that can electronically manipulate tone."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '101\t"Flowers are reborn from the soil and the climate begins to warm, all set to a <e1>score</e1> improvised by an <e2>orchestra</e2> of birds."\n',
#  'Other\n',
#  'Comment: score is not a product\n',
#  '\n',
#  '102\t"He posted the <e1>answers</e1> to the <e2>website</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '103\t"Arcane Subtlety reduced the threat caused by Polymorph by 40% at max rank, though the <e1>threat</e1> caused by the <e2>spell</e2> is minimal."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '104\t"A <e1>programmer</e1> uses a high level <e2>language</e2> to implement its algorithms."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '105\t"The beautiful hydrothermal features in the park (geysers, hot springs, mud pots, etc.), the uplift and subsidence, and many of the <e1>earthquakes</e1> are caused by the <e2>movements</e2> of hydrothermal and/or magmatic fluids."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '106\t"Flowers are nice, but don\'t last very long and the <e1>fruit</e1> in a fruit <e2>basket</e2> often goes bad."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '107\t"He decided to pad the <e1>heel</e1> of <e2>shoes</e2> with a shock absorbing insole or heel pad."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '108\t"From the Scots (Lingle) and French (Ligneul, Lignoul), comes a <e1>shoemaker</e1>\'s sewing <e2>thread</e2>, waxed and bristled (See Waxed End)."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '109\t"One <e1>tablet</e1> per quart was dropped into a <e2>canteen</e2> and made the water safe to drink."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '110\t"The tiny <e1>image</e1> of the Renaissance master is hidden in a <e2>carafe</e2> of wine in his 1597 oil painting Bacchus, one of his most acclaimed works."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '111\t"Then I swept up the dust, which looked like sawdust, and put it in a <e1>plastic container</e1>, which was in a <e2>cabinet</e2> under the granite counter top."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '112\t"In the former method the <e1>acetone</e1> was distilled from an allraline <e2>solution</e2> after the excess oxidant had been destroyed with sodium."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '113\t"In this comprehensive <e1>guide</e1>, over 850 <e2>roses</e2> are described, illustrated, and arranged by group."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment: We can assume that the roses are the topic of the guide.\n',
#  '\n',
#  '114\t"<e1>Chestnut</e1> <e2>flour</e2> was more common than wheat flour in the Italian Alps a century ago."\n',
#  'Entity-Origin(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '115\t"For us the term <e1>artists</e1>\' <e2>book</e2> simply means a book made by an artist; a book made as a work of art rather than as a literary artifact."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a), (d) satisfied\n',
#  '\n',
#  '116\t"My parents bought her a <e1>silver</e1> <e2>necklace</e2> almost identical to the one pictured."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '117\t"Forward <e1>motion</e1> of the vehicle through the air caused a <e2>suction</e2> on the road draft tube."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '118\t"Paul Friedrich guides us through a <e1>babel</e1> of <e2>words</e2>, and worlds of the imagination ranging from his translations from five languages(notably the Russian of his literary studies) to the poetry of the Indian Mexico of his anthropological field work to America writ large -- super highways, a Vermont farm, father and child."\n',
#  'Other\n',
#  'Comment: Webster says: babel: 2 often not capitalized a: a confusion of sounds or voices b: a scene of noise or confusion --- so not a set.\n',
#  '\n',
#  '119\t"The picture below shows a view chapel and west range of the inner <e1>courtyard</e1> of the <e2>castle</e2>."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '120\t"I was attacked by a <e1>flock</e1> of <e2>pigeons</e2> today."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '121\t"That <e1>decision</e1> was also the subject of an unsuccessful <e2>legal challenge</e2>."\n',
#  'Other\n',
#  'Comment: "legal challenge" is not a Message\n',
#  '\n',
#  '122\t"The exit temperature of an effluent <e1>stream</e1> from the low temperature steam reforming <e2>reactor</e2> is not higher than 600 C."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '123\t"Individual <e1>investors</e1> moved into the <e2>property</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '124\t"One of the trickiest <e1>questions</e1> to answer in an interview relates to <e2>salary</e2>."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment: questions are Messages; (b) is satisfied\n',
#  '\n',
#  '125\t"This <e1>tradition</e1> has been narrated in prophet\'s early <e2>biographies</e2>."\n',
#  'Message-Topic(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '126\t"A <e1>thief</e1> who tried to steal the truck broke the igenition with <e2>screwdriver</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '127\t"After the Marian reforms the Legion was notionally a <e1>unit</e1> of heavy <e2>infantrymen</e2> armed with just sword and pilum, but even so it was normally fielded with attached auxiliary skirmishers and missile troops, and incorporated a small cavalry unit."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '128\t"The prosecutors carried <e1>guns</e1> into the <e2>court room</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '129\t"The <e1>malfunctions</e1> on Monday caused <e2>delays</e2> for patrons waiting to check out or renew books at the branches, and impeded access to personal accounts that allow users to renew or hold books online."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '130\t"<e1>Chemical weapons</e1> have been dropped into the <e2>lake</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '131\t"Many other <e1>dwarves</e1> also hailed from this infamous <e2>clan</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '132\t"The <e1>nose</e1> of a <e2>bloodhound</e2> is so good that evidence found by a bloodhound will hold up in matters involving the United States Supreme Court."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '133\t"Global digital music sales grow as the music <e1>industry</e1> develops new business <e2>models</e2>."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a) is satisfied, model is a creative work\n',
#  '\n',
#  '134\t"The <e1>devices</e1> were manufactured at the <e2>factory</e2> in Beaverton well into the 1980s, when production was shifted elsewhere and portions of the factory sold."\n',
#  'Product-Producer(e1,e2)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '135\t"An expensive uniform and a strict ballot rendered it somewhat too exclusive in its character, but in the end it answered its purpose by becoming practically a <e1>muster</e1> of the National <e2>leaders</e2> of the present and the future."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment: A muster is a gathering.\n',
#  '\n',
#  '136\t"The <e1>train ride</e1> from <e2>station</e2> to station is approximate 30 minutes."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '137\t"The archaeological site yields <e1>relics</e1> from long-forgotten <e2>culture</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '138\t"A <e1>maze</e1> of interlocking <e2>jurisdictions</e2> and levels of government confronts average citizens in trying to solve even the simplest of problems."\n',
#  'Other\n',
#  'Comment:This definitely is not a set: it is a pattern, an arrangement.\n',
#  '\n',
#  '139\t"Water <e1>damage</e1> from roof leaks, plumbing leaks or flooding lead to the <e2>growth</e2> of molds."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '140\t"Warm weather is here, and with it comes the <e1>scourge</e1> of <e2>mosquitoes</e2>."\n',
#  'Other\n',
#  'Comment: Like infestation, it is not a set.\n',
#  '\n',
#  '141\t"The <e1>formation</e1> of struvite <e2>stones</e2> is associated with the presence of urea-splitting bacteria, most commonly Proteus mirabilis (but also Klebsiella, Serratia, Providencia species)."\n',
#  'Other\n',
#  'Comment: A process.\n',
#  '\n',
#  '142\t"Our army was successfully engaged during the day with strong rearguards of all arms on the Petit Morin River, thereby materially assisting the progress of the French armies on our right and left, against whom the <e1>enemy</e1> was making his greatest <e2>efforts</e2>."\n',
#  'Other\n',
#  'Comment: Effort is not a concrete object.\n',
#  '\n',
#  '143\t"So when William did cross the Boyne on July 1st 1690, he had an army consisting of the <e1>riffraff</e1> of Europe\'s <e2>mercenaries</e2>."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '144\t"The overall <e1>geometry</e1> of the heart was extracted from the intensity <e2>data</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '145\t"The <e1>discomfort</e1> from the <e2>injury</e2> was now precluding him from his occupation which involved prolonged procedures in the standing position."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '146\t"Flames of purple, pink, yellow and blue dance in the air as a <e1>coven</e1> of <e2>sorcerers</e2> call forth energies from within the Empyrean."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '147\t"Out of the early morning haze, a <e1>convoy</e1> of articulated <e2>lorries</e2> pulls into the Gashouder square."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '148\t"This book has transported <e1>readers</e1> into <e2>ancient times</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment: metaphor, temporal destination (b.4.)\n',
#  '\n',
#  '149\t"We always try to maintain the best <e1>environment</e1> for <e2>programmers</e2>, starting with good salary and conducive working environment."\n',
#  'Other\n',
#  'Comment: We cannot say the programmers actually/directly use the environment.\n',
#  '\n',
#  '150\t"Indeed, a green or black basalt heart <e1>scarab</e1> was found put inside the <e2>body</e2> in its place."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: no movement\n',
#  '\n',
#  '151\t"The first <e1>motorcycle</e1> was manufactured in a small wood <e2>building</e2> with only one room."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '152\t"The <e1>water</e1> pushed to the coast resulted in <e2>tides</e2> as much as three feet above normal, with waves of 5-10 feet atop these tides."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '153\t"The <e1>chapters</e1> in this book investigate <e2>issues</e2> and communities."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '154\t"He rescheduled the birthday <e1>party</e1> to the <e2>next day</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '155\t"The <e1>bacterial aerosol</e1> was generated from an up-draft <e2>nebulizer</e2>."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '156\t"<e1>People</e1> have travelled into <e2>space</e2>, but not the deep ocean."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '157\t"For those of you who are unsure what Afrikaans is, it is a language which originated from the Dutch which were the first settlers in South Africa and the unique <e1>language</e1> was evolved from other <e2>settlers</e2> from Malaya, Indonesia, Madagascar and West Africa."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '158\t"<e1>Beaver</e1> <e2>dams</e2> are created as a protection against predators, such as coyotes, wolves and bears, and to provide easy access to food during winter."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '159\t"So, the theme of the <e1>play</e1> has to do with <e2>religion</e2>."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '160\t"There has been intense <e1>debate</e1> over the circles\' <e2>origins</e2>."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '161\t"I have recently developed creases in my <e1>ear</e1> <e2>lobes</e2>."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '162\t"Manufacturing extra neutral <e1>alcohol</e1> which is the basic ingredient used for making <e2>liquor</e2>, the commodity was largely used by companies making Indian Made Foreign Liquor (IMFL)."\n',
#  'Entity-Origin(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '163\t"Initially the <e1>user</e1> calibrates the microscope with a fluorescence lifetime <e2>standard</e2> positioned at the sample plane."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '164\t"The <e1>province</e1> comprises the southeastern <e2>part</e2> of Panay Island with island-province of Guimaras just across its coast."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '165\t"The <e1>charge</e1> is the source of an electric <e2>field</e2>, which carries energy-the electrostatic self-energy."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '166\t"The <e1>tardiness</e1> however has been caused by the <e2>arrival</e2> of my old man; who in true Bloodworth fashion has had me walking everywhere."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '167\t"The <e1>key</e1> was in a <e2>chest</e2>."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '168\t"The <e1>residue</e1> was distilled from an Arbuzov <e2>flask</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '169\t"As the Gondorians moved forward the evil force started to withdraw, unleashing a <e1>rain</e1> of deadly <e2>arrows</e2> into the heavily armoured Gondorians."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '170\t"It is a medieval Latin <e1>manuscript</e1> relating the early <e2>history</e2> of the Isle of Man."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '171\t"The river had now turned into full <e1>flood</e1> after the <e2>deluge</e2> of rain a few days ago."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '172\t"He stopped rowing when the boat was opposite to the paddle wheel of the steamer, and the <e1>steamer</e1> stopped her <e2>engine</e2> at the same time."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '173\t"This is the <e1>umbrella</e1> that peels the potatoes with a <e2>pencil</e2> and makes a pink ink with the peelings stood up."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment: There seems to be an anthropomorphic characterisation of the umbrella here.\n',
#  '\n',
#  '174\t"This American-style <e1>wheat</e1> <e2>ale</e2> is a light, unfiltered brew with a citrus aroma andflavor imparted by a late addition of lemon grass."\n',
#  'Entity-Origin(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '175\t"The <e1>car</e1> left the <e2>plant</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '176\t"Our experience extends to 15 years continued promotion of this <e1>archipelago</e1> of nine <e2>islands</e2>."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '177\t"To separate the solids at the end of the experiment, the <e1>clay</e1> was contained in a semi- permeable <e2>membrane tubing</e2>."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '178\t"This machine is blowing <e1>sand</e1> into <e2>molds</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '179\t"The <e1>cultivation</e1> consisted of plowing the crop with a double-shovel <e2>plow</e2>."\n',
#  'Other\n',
#  'Comment: Purpose-Tool\n',
#  '\n',
#  '180\t"The final <e1>chapter</e1> offers a <e2>theological survey</e2> of the use of the formula."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment: the chapter is about theology\n',
#  '\n',
#  '181\t"She mentioned the <e1>scandal</e1> caused by a BBC <e2>documentary</e2> on the treatment of children in a special-needs home and asked how the state had responded to these."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '182\t"Isolated fractures of the <e1>shaft</e1> of the <e2>ulna</e2>, without other fractures, often result when the forearm is raised to fend off a blow."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '183\t"We have placed the <e1>candidates</e1> into <e2>roles</e2>."\n',
#  'Other\n',
#  'Comment: violates b.1\n',
#  '\n',
#  '184\t"Frequent agitations throw academic <e1>life</e1> into <e2>disarray</e2>."\n',
#  'Other\n',
#  'Comment: violates c.3\n',
#  '\n',
#  '185\t"Still other examples of the <e1>potter</e1>\'s <e2>ceramics</e2> are clad in slinky assortments of tassels and beads."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '186\t"The <e1>nasal cavity</e1> of <e2>birds</e2> contains turbinates (Bang 1971), cartilaginous structures that are thought to have as one of their functions water recovery from air."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '187\t"Thus, in simple words, a <e1>tendon</e1> attaches a <e2>muscle</e2> to a bone."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '188\t"<e1>Positions</e1> were denoted by <e2>black dots</e2> along the tracks, the adjacent numbers indicating the day of the month."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '189\t"The World Health Organization(WHO) found that the <e1>radiation</e1> release from the Chernobyl <e2>accident</e2> was 200 times that of the Hiroshima and Nagasaki."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '190\t"My dog ate a <e1>cellophane bag</e1> full of <e2>dog treats</e2> on Tuesday."\n',
#  'Content-Container(e2,e1)\n',
#  'Comment: the treas are in the bag\n',
#  '\n',
#  '191\t"The <e1>owl</e1> held the mouse in its <e2>claw</e2>."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '192\t"This is how grain was delivered to the wooden grain bins and <e1>hay</e1> was put inside the upper part of the rock <e2>barn</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '193\t"Police foiled an attempt to kill an <e1>artist</e1> who drew a <e2>cartoon</e2> depicting the Prophet Muhammad that sparked outrage in the Muslim world."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '194\t"When Woody Harrelson received a copy of the screenplay for "Zombieland" last year, he stuffed the <e1>paper</e1> into his duffel <e2>bag</e2> of unread scripts and promptly forgot about it."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '195\t"The city is a <e1>treasure trove</e1> of terrific <e2>libraries</e2>, interesting museums, and wonderful Victorian architecture complemented by the incomparable work of Scotland\'s greatest architect, Charles Rennie Mackintosh."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment: Look at en.wikipedia.org/wiki/Treasure_trove -- it is a collection.\n',
#  '\n',
#  '196\t"We leave the <e1>bail</e1> of the <e2>reel</e2> open and place your the rod in a double mounted set up as shown on the facing page."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '197\t"The Mapungubwe Collection at the University of Pretoria features remarkable <e1>works</e1> from the largely forgotten <e2>kingdom</e2> of Mapungubwe that flourished near the confluence of the Limpopo and Shashe Rivers between 1000 and 1300 AD."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '198\t"Also, in the midst of the <e1>confusion</e1> caused by the <e2>coup</e2>, the issuing of militant posters was a way for artists and organizations to declare their active engagement against the rebellion."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '199\t"The title is taken from an 1813 <e1>book</e1> by a Virginia <e2>planter</e2> and senator named John Taylor."\n',
#  'Product-Producer(e1,e2)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '200\t"In the same way, a <e1>society</e1> is built up of many <e2>individuals</e2>."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '201\t"The <e1>scientist</e1> approached the big cat with a <e2>notepad</e2> and a pencil in her hands."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '202\t"The bottom <e1>photo</e1> is from the New York public <e2>library</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '203\t"The <e1>accident</e1> caused a major traffic <e2>snarl</e2> on the arterial road."\n',
#  'Cause-Effect(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '204\t"Two plane crash survivors have paid a special visit to the Hutt Hospital <e1>surgeon</e1> whose <e2>team</e2> helped to re-build their shattered faces eight years ago."\n',
#  'Other\n',
#  'Comment:The team is not a collection of surgeons.\n',
#  '\n',
#  '205\t"The <e1>dress</e1> was in a <e2>trunk</e2> dated summer of 1938 along with several other dresses from this same period."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example\n',
#  '\n',
#  '206\t"The various forms of idealistic, materialistic and agnostic philosophies are subject to the <e1>tension</e1> caused by the indicated <e2>situation</e2>."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '207\t"From him, Cain learns that Alexis had survived his suicide and became the <e1>leader</e1> of that <e2>organization</e2>, renaming it Delilah."\n',
#  'Member-Collection(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '208\t"James Hagler, Venice\'s <e1>director</e1> of historical resources, has completed a picture <e2>book</e2> of the area\'s buildings."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '209\t"A program has fetched <e1>data</e1> into host variable <e2>arrays</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '210\t"Recently, only insignificant <e1>things</e1> arrive to <e2>theatres</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '211\t"Tissue damage and <e1>electrode</e1> <e2>corrosion</e2> are both associatcd with high charge density stimulation."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '212\t"Two of Walters\'s fingers are inside the <e1>koala</e1> \'s <e2>pouch</e2>."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '213\t"In a former residence, your writer had an atrium containing a <e1>duel</e1> of doves<e2>moles</e2> numbering 22."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '214\t"To stand up to the wind, <e1>umbrella</e1> <e2>frames</e2> are strong yet flexible."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '215\t"<e1>Contractions</e1> of the diaphragm are caused by stimulation of the vagus nerve either by the brain or by <e2>irritation</e2> anywhere along the length of the nerve."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '216\t"A 15 minute <e1>plane</e1> drive from <e2>runway</e2> to terminal is uncommon."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '217\t"The geometric <e1>skeleton</e1> is derived from a static <e2>object</e2> using an implicit \'directions\' method."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '218\t"The <e1>filmmakers</e1> dug a large <e2>hole</e2> in the ground for the scene where the Narnians cause the pillars supporting the growth near Aslan\'s How to collapse on the Telmarines."\n',
#  'Product-Producer(e2,e1)\n',
#  'Comment: (a) is satisfied\n',
#  '\n',
#  '219\t"It is a monthly <e1>report</e1> providing <e2>opinion</e2> and advice on current United States government contract issues."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '220\t"<e1>Governments</e1>, frightened of losing votes, resolved the crisis through <e2>subsidization</e2>."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '221\t"For Christmas, Daniel gave Kelly a Tiffany bracelet, and for Valentine\'s Day he bought a <e1>diamond</e1> <e2>necklace</e2>."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '222\t"We also passed a <e1>wake</e1> of turkey <e2>buzzards</e2>, and I was again glad to not be driving, because my car and I both have shaky nerves still, from the Great Turkey Buzzard Incident of \'08."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '223\t"Plantar <e1>warts</e1> are caused by a <e2>virus</e2> that infects the outer layer of skin on the soles of the feet."\n',
#  'Cause-Effect(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '224\t"The <e1>sensor</e1> was manufactured in a cost effective thin film <e2>process</e2>."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '225\t"The putative left, we see, is just as eager as the nominal right to brand crime and violence with any hint of political motivation as terrorism, and therefore to remove it from the ordinary processes of criminal law and sanction, which are already quite draconian in these United States, and to animate parallel systems of harsher surveillance and punishment for the political <e1>compeers</e1> of such <e2>criminals</e2>."\n',
#  'Other\n',
#  'Comment: Compeer = peer (more or less). Not a set.\n',
#  '\n',
#  '226\t"The <e1>list</e1> of the 10 Most Beautiful Women posted on the official Web site of the 2009 Australian Open was filled with sleek, thin <e2>images</e2>."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '227\t"The <e1>rope</e1> of the <e2>prayer-bell</e2> was there in a perfect state and coiled up."\n',
#  'Component-Whole(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '228\t"One man pours on a liquid while the other <e1>man</e1> stirs the mixture with a wooden <e2>paddle</e2> or spatula."\n',
#  'Instrument-Agency(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '229\t"Besides, the Chinese case also challenges some ideas of RSS theory, including the concept of <e1>alliance</e1> of different social <e2>classes</e2> and the role of working class in democratization."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '230\t"As the US and Colombian military put pressure on drug traffickers, <e1>operations</e1> are migrating into <e2>nearby countries</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '231\t"A conical <e1>cover</e1> preserved in a <e2>ewer</e2> in Athens accords extremely well with the form of these vessels."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example, the ewer has the cover in it\n',
#  '\n',
#  '232\t"The front of the boring <e1>machine</e1> contains tungsten-tipped <e2>picks</e2> that workers guide with the use of laser projections on video screens."\n',
#  'Component-Whole(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '233\t"They incorporated the <e1>immigrant flows</e1> into <e2>microsimulation</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '234\t"I have always felt so relieved that Roy and the <e1>boys</e1> had left the <e2>creek</e2>."\n',
#  'Entity-Origin(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '235\t"The first <e1>report</e1> analyses the adaptation <e2>strategies</e2> of the EU member states."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '236\t"Cook\'s discoveries prepared the way for establishment of a new penal <e1>colony</e1> by the colonial <e2>power</e2>."\n',
#  'Product-Producer(e1,e2)\n',
#  'Comment: we consider power as government\n',
#  '\n',
#  '237\t"This process passes on a health <e1>gene</e1> to the next <e2>generation</e2>."\n',
#  'Other\n',
#  'Comment: violates c.3\n',
#  '\n',
#  '238\t"A <e1>telescope</e1> assists the <e2>eye</e2> chiefly in two ways."\n',
#  'Instrument-Agency(e1,e2)\n',
#  'Comment: we consider the eye as an actor.\n',
#  '\n',
#  '239\t"The <e1>boy</e1> accidentally went into the girl\'s <e2>bathroom</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '240\t"The <e1>document</e1> is stored in the proper <e2>folder</e2> as a text."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example.\n',
#  '\n',
#  '241\t"Unfortunately, they just had brief mentions and more <e1>pages</e1> were spent describing the clubs <e2>scene</e2>."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '242\t"The map to the left shows a snapshot of <e1>weather</e1> <e2>conditions</e2> in selected towns across Italy."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  '243\t"I reflected on this while passing a <e1>passel</e1> of <e2>pigeons</e2> parading on a Loop sidewalk the other day."\n',
#  'Member-Collection(e2,e1)\n',
#  'Comment:\n',
#  '\n',
#  '244\t"The retailers poured <e1>resources</e1> into promoting low-alcohol <e2>wine</e2>."\n',
#  'Other\n',
#  'Comment: resources go to promoting, not to wine=\n',
#  '\n',
#  '245\t"Fiscus was the treasury of the Roman emperor, so-called because the <e1>money</e1> was stored in <e2>baskets</e2>."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: prototypical example; no movement\n',
#  '\n',
#  '246\t"Hundreds of toxic <e1>chemicals</e1> were released into the <e2>atmosphere</e2>."\n',
#  'Entity-Destination(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '247\t"The final <e1>part</e1> of the court is completed by the <e2>chapel</e2>, begun by Mary I in 1554 in memory of her father."\n',
#  'Other\n',
#  'Comment: part is not a producer\n',
#  '\n',
#  '248\t"<e1>Mobile</e1> lost in the ocean was found in a cod <e2>belly</e2>."\n',
#  'Content-Container(e1,e2)\n',
#  'Comment: the mobile was contained in the belly of the cod (2) is satisfied\n',
#  '\n',
#  '249\t"The <e1>flyer</e1> advertised a two-week <e2>workshop</e2> being conducted at the university this summer."\n',
#  'Message-Topic(e1,e2)\n',
#  'Comment:\n',
#  '\n',
#  '250\t"The <e1>hotel</e1> arose from the <e2>reconstruction</e2> of historical building."\n',
#  'Other\n',
#  'Comment:\n',
#  '\n',
#  ...]

# %%
def prepare_dataset(raw):
    sentences, relations = [], []
    to_replace = [("\"", ""), ("\n", ""), ("<", " <"), (">", "> ")]
    last_was_sentence = False
    for line in raw:
        sl = line.split("\t")
        if last_was_sentence:
            relations.append(sl[0].split("(")[0].replace("\n", ""))
            last_was_sentence = False
        if sl[0].isdigit():
            sent = sl[1]
            for rp in to_replace:
                sent = sent.replace(rp[0], rp[1])
            sentences.append(sent)
            last_was_sentence = True
    print("Found {} sentences".format(len(sentences)))
    return sentences, relations

# %%
sentences, relations = prepare_dataset(train_file)
# Out:
# Found 8000 sentences

# %%
import pandas as pd
final = pd.DataFrame({'SENTENCES':sentences, 'RELATIONS': relations})

causeeffect = final[final['RELATIONS']=='Cause-Effect']

# %%
len(causeeffect)
# Out:
# 1003

# %%
def preprocess(raw_text):
    # keep only words
    #letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)

    # convert to lower case and split 
    #words = letters_only_text.lower()
    words = raw_text.lower()
    
    # transform cause-effects keywords
    text_1 = words.replace("<e1> ", "<e1>")
    text_2 = text_1.replace("<e2> ", "<e2>")
    text_3 = text_2.replace(" </e1> ", "</e1>")
    text_4 = text_3.replace(" </e2> ", "</e2>")
    
    # convert string into list of words
    list_of_words = text_4.split()
    
    return list_of_words

def identify_nature_of_words_for_a_sentence(raw_text):
    # clean my sentences
    list_of_words = preprocess(raw_text)
    
    # labelized words of my sentences
    nature_of_sentences = []
    for word in list_of_words:
        if '<e1>' in word:
            result_nature_of_word = 'cause'
        elif '<e2>' in word:
            result_nature_of_word = 'consequence'
        else:
            result_nature_of_word = 'neutral'
        nature_of_sentences.append(result_nature_of_word)
    
    return nature_of_sentences

def give_me_my_sentences_into_graph(raw_text):
    import re
    # keep only words
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)
    
    # clean my sentences
    list_of_words = preprocess(letters_only_text)
    list_of_words_cleaned = [word for word in list_of_words if word != 'e']
    
    # transform into dataframes of pair tokens
    word_1 = []; word_2 = []
    for num in range(len(list_of_words_cleaned)-1):
        word_1.append(list_of_words_cleaned[num]);  word_2.append(list_of_words_cleaned[num+1])
    
    try:
        graph_of_pair_of_words_dataframe = pd.DataFrame({'from':word_1, 'to': word_2})
    except:
        print('Sorry, there are more <from> than <to>')
    
    return graph_of_pair_of_words_dataframe

def give_me_nature_of_my_sentences_for_graph(raw_text):
    import re
    # keep only words
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)
    
    # clean my sentences
    list_of_words = preprocess(letters_only_text)
    list_of_words_cleaned = [word for word in list_of_words if word != 'e']
    
    # retrieve nature of my words
    nature_of_words = identify_nature_of_words_for_a_sentence(raw_text)
    
    try:
        labelisation_of_words = pd.DataFrame({'id':list_of_words_cleaned, 'group': nature_of_words})
        labelisation_of_words = labelisation_of_words.drop_duplicates()
        print('Done because : NATURE -> ', len(nature_of_words), '<- and WORDS ->', len(list_of_words_cleaned))
    except:
        print('!! FAILURE !! because : NATURE -> ', len(nature_of_words), '<- and WORDS ->', len(list_of_words_cleaned))
        labelisation_of_words = None
    
    return labelisation_of_words

# %%
text = causeeffect['SENTENCES'].iloc[10]

# %%
text
# Out:
# 'A neoplastic  <e1> recurrence </e1>  arose from an extensive  <e2> radiation </e2>  induced ulceration.'

# %%
nature = give_me_nature_of_my_sentences_for_graph(text)
words = give_me_my_sentences_into_graph(text)
# Out:
# Done because : NATURE ->  10 <- and WORDS -> 10

# %%
words
# Out:
#          from          to
# 0           a  neoplastic
# 1  neoplastic  recurrence
# 2  recurrence       arose
# 3       arose        from
# 4        from          an
# 5          an   extensive
# 6   extensive   radiation
# 7   radiation     induced
# 8     induced  ulceration

# %%
id_word_total = []
group_total = []
id_sentence = []
index_nodes = []

for item in range(len(causeeffect)):
    try:
        id_word_total.append(give_me_nature_of_my_sentences_for_graph(causeeffect['SENTENCES'].iloc[item]).id.tolist())
        group_total.append(give_me_nature_of_my_sentences_for_graph(causeeffect['SENTENCES'].iloc[item]).group.tolist())
        index_nodes.append(item)
    except:
        print('No id')
        
id_sentence = []
for i in range(len(id_word_total)):
    id_sentence.append(['sentence_id_'+str(i)]*(len(id_word_total[i])))
# Out:
# !! FAILURE !! because : NATURE ->  35 <- and WORDS -> 36
# No id
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 26
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 26
# No id
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  35 <- and WORDS -> 34
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  15 <- and WORDS -> 14
# No id
# Done because : NATURE ->  40 <- and WORDS -> 40
# Done because : NATURE ->  40 <- and WORDS -> 40
# !! FAILURE !! because : NATURE ->  39 <- and WORDS -> 38
# No id
# !! FAILURE !! because : NATURE ->  35 <- and WORDS -> 36
# No id
# Done because : NATURE ->  43 <- and WORDS -> 43
# Done because : NATURE ->  43 <- and WORDS -> 43
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 21
# No id
# !! FAILURE !! because : NATURE ->  32 <- and WORDS -> 33
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  33 <- and WORDS -> 33
# Done because : NATURE ->  33 <- and WORDS -> 33
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 23
# No id
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 16
# No id
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  27 <- and WORDS -> 28
# No id
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  31 <- and WORDS -> 31
# Done because : NATURE ->  31 <- and WORDS -> 31
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 19
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# !! FAILURE !! because : NATURE ->  29 <- and WORDS -> 31
# No id
# !! FAILURE !! because : NATURE ->  23 <- and WORDS -> 24
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  7 <- and WORDS -> 7
# Done because : NATURE ->  7 <- and WORDS -> 7
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 24
# No id
# !! FAILURE !! because : NATURE ->  11 <- and WORDS -> 12
# No id
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  27 <- and WORDS -> 27
# !! FAILURE !! because : NATURE ->  23 <- and WORDS -> 22
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 14
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 23
# No id
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 26
# No id
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  9 <- and WORDS -> 7
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 19
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  32 <- and WORDS -> 32
# Done because : NATURE ->  32 <- and WORDS -> 32
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 12
# No id
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 24
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# !! FAILURE !! because : NATURE ->  20 <- and WORDS -> 21
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 26
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 23
# No id
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 25
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 17
# No id
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  20 <- and WORDS -> 17
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  30 <- and WORDS -> 30
# Done because : NATURE ->  30 <- and WORDS -> 30
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  12 <- and WORDS -> 13
# No id
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  28 <- and WORDS -> 28
# !! FAILURE !! because : NATURE ->  9 <- and WORDS -> 8
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  20 <- and WORDS -> 21
# No id
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 17
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  27 <- and WORDS -> 28
# No id
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 26
# No id
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 25
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  30 <- and WORDS -> 30
# Done because : NATURE ->  30 <- and WORDS -> 30
# Done because : NATURE ->  31 <- and WORDS -> 31
# Done because : NATURE ->  31 <- and WORDS -> 31
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  34 <- and WORDS -> 34
# Done because : NATURE ->  34 <- and WORDS -> 34
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 22
# No id
# Done because : NATURE ->  30 <- and WORDS -> 30
# Done because : NATURE ->  30 <- and WORDS -> 30
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  32 <- and WORDS -> 31
# No id
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 20
# No id
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 23
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  36 <- and WORDS -> 33
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# !! FAILURE !! because : NATURE ->  30 <- and WORDS -> 32
# No id
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  15 <- and WORDS -> 16
# No id
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# !! FAILURE !! because : NATURE ->  28 <- and WORDS -> 29
# No id
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 27
# No id
# Done because : NATURE ->  5 <- and WORDS -> 5
# Done because : NATURE ->  5 <- and WORDS -> 5
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 17
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# !! FAILURE !! because : NATURE ->  32 <- and WORDS -> 30
# No id
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  6 <- and WORDS -> 6
# Done because : NATURE ->  6 <- and WORDS -> 6
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  6 <- and WORDS -> 6
# Done because : NATURE ->  6 <- and WORDS -> 6
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 27
# No id
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 20
# No id
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  33 <- and WORDS -> 34
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 14
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  6 <- and WORDS -> 6
# Done because : NATURE ->  6 <- and WORDS -> 6
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 16
# No id
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  32 <- and WORDS -> 33
# No id
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 21
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 21
# No id
# !! FAILURE !! because : NATURE ->  57 <- and WORDS -> 56
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  38 <- and WORDS -> 38
# Done because : NATURE ->  38 <- and WORDS -> 38
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  12 <- and WORDS -> 11
# No id
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 24
# No id
# !! FAILURE !! because : NATURE ->  33 <- and WORDS -> 32
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# !! FAILURE !! because : NATURE ->  29 <- and WORDS -> 31
# No id
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# !! FAILURE !! because : NATURE ->  23 <- and WORDS -> 22
# No id
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 21
# No id
# !! FAILURE !! because : NATURE ->  27 <- and WORDS -> 26
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# !! FAILURE !! because : NATURE ->  11 <- and WORDS -> 12
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  37 <- and WORDS -> 37
# Done because : NATURE ->  37 <- and WORDS -> 37
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 14
# No id
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 23
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 12
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 20
# No id
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 18
# No id
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 23
# No id
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 25
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# !! FAILURE !! because : NATURE ->  9 <- and WORDS -> 10
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 18
# No id
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# !! FAILURE !! because : NATURE ->  11 <- and WORDS -> 12
# No id
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# !! FAILURE !! because : NATURE ->  31 <- and WORDS -> 32
# No id
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# !! FAILURE !! because : NATURE ->  32 <- and WORDS -> 30
# No id
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  20 <- and WORDS -> 19
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 27
# No id
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 22
# No id
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 25
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# !! FAILURE !! because : NATURE ->  35 <- and WORDS -> 33
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 23
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 18
# No id
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 18
# No id
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  36 <- and WORDS -> 36
# Done because : NATURE ->  36 <- and WORDS -> 36
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  29 <- and WORDS -> 29
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  35 <- and WORDS -> 35
# Done because : NATURE ->  35 <- and WORDS -> 35
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# !! FAILURE !! because : NATURE ->  12 <- and WORDS -> 13
# No id
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 17
# No id
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 12
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# !! FAILURE !! because : NATURE ->  30 <- and WORDS -> 31
# No id
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 22
# No id
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# !! FAILURE !! because : NATURE ->  43 <- and WORDS -> 44
# No id
# Done because : NATURE ->  7 <- and WORDS -> 7
# Done because : NATURE ->  7 <- and WORDS -> 7
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# !! FAILURE !! because : NATURE ->  15 <- and WORDS -> 16
# No id
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  34 <- and WORDS -> 34
# Done because : NATURE ->  34 <- and WORDS -> 34
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 19
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# !! FAILURE !! because : NATURE ->  12 <- and WORDS -> 13
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  37 <- and WORDS -> 37
# Done because : NATURE ->  37 <- and WORDS -> 37
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 14
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# !! FAILURE !! because : NATURE ->  43 <- and WORDS -> 44
# No id
# !! FAILURE !! because : NATURE ->  12 <- and WORDS -> 13
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# !! FAILURE !! because : NATURE ->  29 <- and WORDS -> 30
# No id
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 20
# No id
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  47 <- and WORDS -> 48
# No id
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# !! FAILURE !! because : NATURE ->  28 <- and WORDS -> 27
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 22
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  20 <- and WORDS -> 21
# No id
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 25
# No id
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 15
# No id
# !! FAILURE !! because : NATURE ->  23 <- and WORDS -> 25
# No id
# !! FAILURE !! because : NATURE ->  12 <- and WORDS -> 14
# No id
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 17
# No id
# !! FAILURE !! because : NATURE ->  28 <- and WORDS -> 27
# No id
# !! FAILURE !! because : NATURE ->  34 <- and WORDS -> 33
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 23
# No id
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 14
# No id
# Done because : NATURE ->  30 <- and WORDS -> 30
# Done because : NATURE ->  30 <- and WORDS -> 30
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 25
# No id
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# !! FAILURE !! because : NATURE ->  11 <- and WORDS -> 9
# No id
# !! FAILURE !! because : NATURE ->  9 <- and WORDS -> 10
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# !! FAILURE !! because : NATURE ->  20 <- and WORDS -> 18
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 18
# No id
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  21 <- and WORDS -> 21
# ...
# Done because : NATURE ->  35 <- and WORDS -> 35
# Done because : NATURE ->  35 <- and WORDS -> 35
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  36 <- and WORDS -> 36
# Done because : NATURE ->  36 <- and WORDS -> 36
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# !! FAILURE !! because : NATURE ->  23 <- and WORDS -> 24
# No id
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# !! FAILURE !! because : NATURE ->  10 <- and WORDS -> 11
# No id
# !! FAILURE !! because : NATURE ->  33 <- and WORDS -> 32
# No id
# !! FAILURE !! because : NATURE ->  6 <- and WORDS -> 8
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  7 <- and WORDS -> 7
# Done because : NATURE ->  7 <- and WORDS -> 7
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 25
# No id
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 23
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  37 <- and WORDS -> 38
# No id
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 26
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# !! FAILURE !! because : NATURE ->  28 <- and WORDS -> 27
# No id
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 26
# No id
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# !! FAILURE !! because : NATURE ->  15 <- and WORDS -> 16
# No id
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 23
# No id
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 27
# No id
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  27 <- and WORDS -> 27
# Done because : NATURE ->  27 <- and WORDS -> 27
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 17
# No id
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  9 <- and WORDS -> 10
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 13
# No id
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# !! FAILURE !! because : NATURE ->  28 <- and WORDS -> 29
# No id
# !! FAILURE !! because : NATURE ->  32 <- and WORDS -> 34
# No id
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  52 <- and WORDS -> 52
# Done because : NATURE ->  52 <- and WORDS -> 52
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# !! FAILURE !! because : NATURE ->  29 <- and WORDS -> 30
# No id
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  33 <- and WORDS -> 34
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 15
# No id
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 18
# No id
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# !! FAILURE !! because : NATURE ->  16 <- and WORDS -> 17
# No id
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 17
# No id
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 14
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  28 <- and WORDS -> 28
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  32 <- and WORDS -> 32
# Done because : NATURE ->  32 <- and WORDS -> 32
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 25
# No id
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 20
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  24 <- and WORDS -> 24
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  10 <- and WORDS -> 11
# No id
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  7 <- and WORDS -> 7
# Done because : NATURE ->  7 <- and WORDS -> 7
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# !! FAILURE !! because : NATURE ->  31 <- and WORDS -> 30
# No id
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  21 <- and WORDS -> 22
# No id
# !! FAILURE !! because : NATURE ->  28 <- and WORDS -> 26
# No id
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# !! FAILURE !! because : NATURE ->  38 <- and WORDS -> 40
# No id
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 15
# No id
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  15 <- and WORDS -> 16
# No id
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 23
# No id
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 16
# No id
# !! FAILURE !! because : NATURE ->  13 <- and WORDS -> 12
# No id
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# !! FAILURE !! because : NATURE ->  24 <- and WORDS -> 26
# No id
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# !! FAILURE !! because : NATURE ->  8 <- and WORDS -> 9
# No id
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 18
# No id
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  22 <- and WORDS -> 22
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  15 <- and WORDS -> 15
# Done because : NATURE ->  21 <- and WORDS -> 21
# Done because : NATURE ->  21 <- and WORDS -> 21
# !! FAILURE !! because : NATURE ->  26 <- and WORDS -> 25
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  37 <- and WORDS -> 37
# Done because : NATURE ->  37 <- and WORDS -> 37
# !! FAILURE !! because : NATURE ->  23 <- and WORDS -> 22
# No id
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# !! FAILURE !! because : NATURE ->  20 <- and WORDS -> 18
# No id
# !! FAILURE !! because : NATURE ->  28 <- and WORDS -> 29
# No id
# !! FAILURE !! because : NATURE ->  53 <- and WORDS -> 51
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  4 <- and WORDS -> 4
# Done because : NATURE ->  4 <- and WORDS -> 4
# Done because : NATURE ->  4 <- and WORDS -> 4
# Done because : NATURE ->  4 <- and WORDS -> 4
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# !! FAILURE !! because : NATURE ->  17 <- and WORDS -> 19
# No id
# !! FAILURE !! because : NATURE ->  27 <- and WORDS -> 26
# No id
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  26 <- and WORDS -> 26
# Done because : NATURE ->  17 <- and WORDS -> 17
# Done because : NATURE ->  17 <- and WORDS -> 17
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 19
# No id
# !! FAILURE !! because : NATURE ->  11 <- and WORDS -> 9
# No id
# Done because : NATURE ->  16 <- and WORDS -> 16
# Done because : NATURE ->  16 <- and WORDS -> 16
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 18
# No id
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  35 <- and WORDS -> 35
# Done because : NATURE ->  35 <- and WORDS -> 35
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  10 <- and WORDS -> 10
# Done because : NATURE ->  40 <- and WORDS -> 40
# Done because : NATURE ->  40 <- and WORDS -> 40
# !! FAILURE !! because : NATURE ->  43 <- and WORDS -> 44
# No id
# !! FAILURE !! because : NATURE ->  14 <- and WORDS -> 16
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# !! FAILURE !! because : NATURE ->  12 <- and WORDS -> 11
# No id
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# !! FAILURE !! because : NATURE ->  25 <- and WORDS -> 27
# No id
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  23 <- and WORDS -> 23
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  25 <- and WORDS -> 25
# Done because : NATURE ->  25 <- and WORDS -> 25
# !! FAILURE !! because : NATURE ->  37 <- and WORDS -> 38
# No id
# !! FAILURE !! because : NATURE ->  22 <- and WORDS -> 21
# No id
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  20 <- and WORDS -> 20
# Done because : NATURE ->  4 <- and WORDS -> 4
# Done because : NATURE ->  4 <- and WORDS -> 4
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  19 <- and WORDS -> 19
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  8 <- and WORDS -> 8
# Done because : NATURE ->  8 <- and WORDS -> 8
# !! FAILURE !! because : NATURE ->  23 <- and WORDS -> 24
# No id
# !! FAILURE !! because : NATURE ->  18 <- and WORDS -> 17
# No id
# !! FAILURE !! because : NATURE ->  19 <- and WORDS -> 20
# No id
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  12 <- and WORDS -> 12
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  14 <- and WORDS -> 14
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  13 <- and WORDS -> 13
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  9 <- and WORDS -> 9
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  18 <- and WORDS -> 18
# Done because : NATURE ->  11 <- and WORDS -> 11
# Done because : NATURE ->  11 <- and WORDS -> 11

# %%
def flatten_list(nested_list):
    from functools import reduce
    result = reduce(lambda x,y: x+y,nested_list)
    return result

# %%
id_word_total = flatten_list(id_word_total)
group_total = flatten_list(group_total)
id_sentence = flatten_list(id_sentence)

#nature = pd.DataFrame({'id':id_word_total, 'group': group_total, 'which_sentence':id_sentence})

# %%
print("id_word_total:", len(id_word_total), "||","group_total:", len(group_total), "||","id_sentence:", len(id_sentence))
# Out:
# id_word_total: 11602 || group_total: 11602 || id_sentence: 11602

# %%
nature = pd.DataFrame({'id':id_word_total, 'group': group_total, 'which_sentence':id_sentence})
nature.to_excel('nature.xlsx')

# %% [markdown]
# ### Nodes

# %%
causeeffect = causeeffect.reset_index()
causeeffect['index'] = causeeffect.index
causeeffect = causeeffect[causeeffect['index'].isin(index_nodes)]

# %%
from_word_total = []
to_word_total = []

for item in range(len(causeeffect)):
    try:
        from_word_total.append(give_me_my_sentences_into_graph(causeeffect['SENTENCES'].iloc[item])['from'].tolist())
        print(from_word_total)
        to_word_total.append(give_me_my_sentences_into_graph(causeeffect['SENTENCES'].iloc[item])['to'].tolist())
    except:
        print('No id')
        
id_sentence_v2 = []
for i in range(len(from_word_total)):
    id_sentence_v2.append(['sentence_id_'+str(i)]*(len(from_word_total[i])))
# Out:
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days'], ['the', 'world', 'health', 'organization', 'who', 'found', 'that', 'the', 'radiation', 'release', 'from', 'the', 'chernobyl', 'accident', 'was', 'times', 'that', 'of', 'the', 'hiroshima', 'and']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days'], ['the', 'world', 'health', 'organization', 'who', 'found', 'that', 'the', 'radiation', 'release', 'from', 'the', 'chernobyl', 'accident', 'was', 'times', 'that', 'of', 'the', 'hiroshima', 'and'], ['also', 'in', 'the', 'midst', 'of', 'the', 'confusion', 'caused', 'by', 'the', 'coup', 'the', 'issuing', 'of', 'militant', 'posters', 'was', 'a', 'way', 'for', 'artists', 'and', 'organizations', 'to', 'declare', 'their', 'active', 'engagement', 'against', 'the']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days'], ['the', 'world', 'health', 'organization', 'who', 'found', 'that', 'the', 'radiation', 'release', 'from', 'the', 'chernobyl', 'accident', 'was', 'times', 'that', 'of', 'the', 'hiroshima', 'and'], ['also', 'in', 'the', 'midst', 'of', 'the', 'confusion', 'caused', 'by', 'the', 'coup', 'the', 'issuing', 'of', 'militant', 'posters', 'was', 'a', 'way', 'for', 'artists', 'and', 'organizations', 'to', 'declare', 'their', 'active', 'engagement', 'against', 'the'], ['the', 'accident', 'caused', 'a', 'major', 'traffic', 'snarl', 'on', 'the', 'arterial']]
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days'], ['the', 'world', 'health', 'organization', 'who', 'found', 'that', 'the', 'radiation', 'release', 'from', 'the', 'chernobyl', 'accident', 'was', 'times', 'that', 'of', 'the', 'hiroshima', 'and'], ['also', 'in', 'the', 'midst', 'of', 'the', 'confusion', 'caused', 'by', 'the', 'coup', 'the', 'issuing', 'of', 'militant', 'posters', 'was', 'a', 'way', 'for', 'artists', 'and', 'organizations', 'to', 'declare', 'their', 'active', 'engagement', 'against', 'the'], ['the', 'accident', 'caused', 'a', 'major', 'traffic', 'snarl', 'on', 'the', 'arterial'], ['the', 'various', 'forms', 'of', 'idealistic', 'materialistic', 'and', 'agnostic', 'philosophies', 'are', 'subject', 'to', 'the', 'tension', 'caused', 'by ...
# ...
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days'], ['the', 'world', 'health', 'organization', 'who', 'found', 'that', 'the', 'radiation', 'release', 'from', 'the', 'chernobyl', 'accident', 'was', 'times', 'that', 'of', 'the', 'hiroshima', 'and'], ['also', 'in', 'the', 'midst', 'of', 'the', 'confusion', 'caused', 'by', 'the', 'coup', 'the', 'issuing', 'of', 'militant', 'posters', 'was', 'a', 'way', 'for', 'artists', 'and', 'organizations', 'to', 'declare', 'their', 'active', 'engagement', 'against', 'the'], ['the', 'accident', 'caused', 'a', 'major', 'traffic', 'snarl', 'on', 'the', 'arterial'], ['the', 'various', 'forms', 'of', 'idealistic', 'materialistic', 'and', 'agnostic', 'philosophies', 'are', 'subject', 'to', 'the', 'tension', 'caused', 'by ...
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days'], ['the', 'world', 'health', 'organization', 'who', 'found', 'that', 'the', 'radiation', 'release', 'from', 'the', 'chernobyl', 'accident', 'was', 'times', 'that', 'of', 'the', 'hiroshima', 'and'], ['also', 'in', 'the', 'midst', 'of', 'the', 'confusion', 'caused', 'by', 'the', 'coup', 'the', 'issuing', 'of', 'militant', 'posters', 'was', 'a', 'way', 'for', 'artists', 'and', 'organizations', 'to', 'declare', 'their', 'active', 'engagement', 'against', 'the'], ['the', 'accident', 'caused', 'a', 'major', 'traffic', 'snarl', 'on', 'the', 'arterial'], ['the', 'various', 'forms', 'of', 'idealistic', 'materialistic', 'and', 'agnostic', 'philosophies', 'are', 'subject', 'to', 'the', 'tension', 'caused', 'by ...
# [['the', 'burst', 'has', 'been', 'caused', 'by', 'water', 'hammer'], ['the', 'singer', 'who', 'performed', 'three', 'of', 'the', 'nominated', 'songs', 'also', 'caused', 'a', 'commotion', 'on', 'the', 'red'], ['he', 'had', 'chest', 'pains', 'and', 'headaches', 'from', 'mold', 'in', 'the'], ['financial', 'stress', 'is', 'one', 'of', 'the', 'main', 'causes', 'of'], ['the', 'women', 'that', 'caused', 'the', 'accident', 'was', 'on', 'the', 'cell', 'phone', 'and', 'ran', 'thru', 'the', 'intersection', 'without', 'pausing', 'on', 'the'], ['calluses', 'are', 'caused', 'by', 'improperly', 'fitting', 'shoes', 'or', 'by', 'a', 'skin'], ['the', 'radiation', 'from', 'the', 'atomic', 'bomb', 'explosion', 'is', 'a', 'typical', 'acute'], ['a', 'neoplastic', 'recurrence', 'arose', 'from', 'an', 'extensive', 'radiation', 'induced'], ['he', 'has', 'a', 'tattoo', 'on', 'his', 'right', 'arm', 'and', 'scars', 'from', 'stitches', 'on', 'his', 'right'], ['the', 'continuing', 'nigerian', 'outbreak', 'is', 'the', 'biggest', 'ever', 'caused', 'by', 'the'], ['the', 'fire', 'inside', 'wtc', 'was', 'caused', 'by', 'exploding'], ['the', 'suffering', 'caused', 'by', 'the', 'terrorists', 'is', 'the', 'real'], ['leakage', 'and', 'fire', 'caused', 'due', 'to', 'corrosion', 'of', 'bypass', 'piping', 'for', 'recirculation', 'gas', 'at', 'a', 'fuel', 'oil', 'desulphurization'], ['the', 'metal', 'ball', 'makes', 'a', 'ding', 'ding', 'ding', 'noise', 'when', 'it', 'swings', 'back', 'and', 'hits', 'the', 'metal', 'body', 'of', 'the'], ['ai', 'requested', 'that', 'the', 'perpetrators', 'be', 'prosecuted', 'to', 'the', 'fullest', 'extent', 'of', 'the', 'law', 'that', 'adequate', 'compensation', 'be', 'provided', 'to', 'the', 'victims', 'and', 'that', 'senior', 'government', 'and', 'police', 'officials', 'offer', 'apologies', 'for', 'the', 'suffering', 'caused', 'by', 'the', 'responsible', 'police'], ['guitars', 'are', 'played', 'acoustically', 'the', 'tone', 'is', 'produced', 'by', 'the', 'vibration', 'of', 'the', 'strings', 'which', 'is', 'amplified', 'by', 'the', 'body', 'of', 'the', 'guitar', 'which', 'acts', 'as', 'a', 'large', 'hollow', 'resonating', 'chamber', 'or', 'they', 'may', 'rely', 'on', 'an', 'amplifier', 'that', 'can', 'electronically', 'manipulate'], ['forward', 'motion', 'of', 'the', 'vehicle', 'through', 'the', 'air', 'caused', 'a', 'suction', 'on', 'the', 'road', 'draft'], ['the', 'malfunctions', 'on', 'monday', 'caused', 'delays', 'for', 'patrons', 'waiting', 'to', 'check', 'out', 'or', 'renew', 'books', 'at', 'the', 'branches', 'and', 'impeded', 'access', 'to', 'personal', 'accounts', 'that', 'allow', 'users', 'to', 'renew', 'or', 'hold', 'books'], ['water', 'damage', 'from', 'roof', 'leaks', 'plumbing', 'leaks', 'or', 'flooding', 'lead', 'to', 'the', 'growth', 'of'], ['the', 'discomfort', 'from', 'the', 'injury', 'was', 'now', 'precluding', 'him', 'from', 'his', 'occupation', 'which', 'involved', 'prolonged', 'procedures', 'in', 'the', 'standing'], ['the', 'tardiness', 'however', 'has', 'been', 'caused', 'by', 'the', 'arrival', 'of', 'my', 'old', 'man', 'who', 'in', 'true', 'bloodworth', 'fashion', 'has', 'had', 'me', 'walking'], ['the', 'river', 'had', 'now', 'turned', 'into', 'full', 'flood', 'after', 'the', 'deluge', 'of', 'rain', 'a', 'few', 'days'], ['the', 'world', 'health', 'organization', 'who', 'found', 'that', 'the', 'radiation', 'release', 'from', 'the', 'chernobyl', 'accident', 'was', 'times', 'that', 'of', 'the', 'hiroshima', 'and'], ['also', 'in', 'the', 'midst', 'of', 'the', 'confusion', 'caused', 'by', 'the', 'coup', 'the', 'issuing', 'of', 'militant', 'posters', 'was', 'a', 'way', 'for', 'artists', 'and', 'organizations', 'to', 'declare', 'their', 'active', 'engagement', 'against', 'the'], ['the', 'accident', 'caused', 'a', 'major', 'traffic', 'snarl', 'on', 'the', 'arterial'], ['the', 'various', 'forms', 'of', 'idealistic', 'materialistic', 'and', 'agnostic', 'philosophies', 'are', 'subject', 'to', 'the', 'tension', 'caused', 'by ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from_word_total = flatten_list(from_word_total)
to_word_total = flatten_list(to_word_total)
id_sentence_v2 = flatten_list(id_sentence_v2)

# %%
print("from_word_total:", len(from_word_total), "||","to_word_total:", len(to_word_total), "||","id_sentence_v2:", len(id_sentence_v2))
# Out:
# from_word_total: 12296 || to_word_total: 12296 || id_sentence_v2: 12296

# %%
words = pd.DataFrame({'from':from_word_total, 'to': to_word_total, 'which_sentence':id_sentence_v2})
words.to_excel('word.xlsx')

# %%
words

# %% [markdown]
# # New Approach

# %%
from nltk import sent_tokenize, word_tokenize, pos_tag
import nltk

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\adsieg\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def get_postag(string):
    string = nltk.word_tokenize(string)
    pos_string = nltk.pos_tag(string)
    return pos_string

def transform_get_postag_into_dataframe(string):
    import re
    # keep only words
    letters_only_text = re.sub("[^a-zA-Z]", " ", string)
    
    # clean my sentences
    list_of_words = preprocess(letters_only_text)
    list_of_words_cleaned = [word for word in list_of_words if word != 'e']
    list_of_words_cleaned = " ".join(list_of_words_cleaned)
    
    # new algo
    pos_string = get_postag(list_of_words_cleaned)
    word = [word[0] for word in pos_string]
    nature = [word[1] for word in pos_string]
    result_item_sentence = []
    for item in nature:
        if item in ['NN', 'JJ', 'NNS']:
            result_item = 'cause_consequence'
            result_item_sentence.append(result_item)
        else:
            result_item = 'neutral'
            result_item_sentence.append(result_item)
    result = pd.DataFrame({'id':word, 'group': nature, 'qualif':result_item_sentence})
    
    return result

def sentences_into_graph(raw_text):
    import re
    # keep only words
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)
    
    # clean my sentences
    list_of_words = preprocess(letters_only_text)
    list_of_words_cleaned = [word for word in list_of_words if word != 'e']
    
    # transform into dataframes of pair tokens
    word_1 = []; word_2 = []
    for num in range(len(list_of_words_cleaned)-1):
        word_1.append(list_of_words_cleaned[num]);  word_2.append(list_of_words_cleaned[num+1])
    
    try:
        graph_of_pair_of_words_dataframe = pd.DataFrame({'from':word_1, 'to': word_2})
    except:
        print('Sorry, there are more <from> than <to>')
    
    return graph_of_pair_of_words_dataframe

# %% [markdown]
# ### Nodes

# %%
data_df = transform_get_postag_into_dataframe('A neoplastic recurrence arose from an extensive radiation induced ulceration')

# %%
text = causeeffect['SENTENCES'].iloc[10]

# %%
text
# Out:
# 'The  <e1> fire </e1>  inside WTC was caused by exploding  <e2> fuel </e2> .'

# %%
transform_get_postag_into_dataframe(text)
# Out:
#           id group             qualif
# 0        the    DT            neutral
# 1       fire    NN  cause_consequence
# 2     inside    IN            neutral
# 3        wtc    NN  cause_consequence
# 4        was   VBD            neutral
# 5     caused   VBN            neutral
# 6         by    IN            neutral
# 7  exploding   VBG            neutral
# 8       fuel    NN  cause_consequence

# %%
id_word_total = []
group_total = []
qualif_total = []

for item in range(len(causeeffect)):
    try:
        # computation
        buffer_df = transform_get_postag_into_dataframe(causeeffect['SENTENCES'].iloc[item])
        # stockage
        id_word_total.append(buffer_df['id'].tolist())
        group_total.append(buffer_df['group'].tolist())
        qualif_total.append(buffer_df['qualif'].tolist())
    except:
        print('No id')
        
id_sentence = []
for i in range(len(id_word_total)):
    id_sentence.append(['sentence_id_'+str(i)]*(len(id_word_total[i])))

# %%
def flatten_list(nested_list):
    from functools import reduce
    result = reduce(lambda x,y: x+y,nested_list)
    return result

id_word_total = flatten_list(id_word_total)
group_total = flatten_list(group_total)
qualif_total = flatten_list(qualif_total)
id_sentence = flatten_list(id_sentence)

# %%
print("id_word_total:", len(id_word_total), "||","group_total:", len(group_total), "||","qualif_total:", len(qualif_total), "||","id_sentence:", len(id_sentence))
# Out:
# id_word_total: 13034 || group_total: 13034 || qualif_total: 13034 || id_sentence: 13034

# %%
nodes = pd.DataFrame({'id':id_word_total, 'group': group_total, 'qualif':qualif_total,'which_sentence':id_sentence})

# %%
nodes
# Out:
#                id group             qualif   which_sentence
# 0             the    DT            neutral    sentence_id_0
# 1           burst    NN  cause_consequence    sentence_id_0
# 2             has   VBZ            neutral    sentence_id_0
# 3            been   VBN            neutral    sentence_id_0
# 4          caused   VBN            neutral    sentence_id_0
# 5              by    IN            neutral    sentence_id_0
# 6           water    NN  cause_consequence    sentence_id_0
# 7          hammer    NN  cause_consequence    sentence_id_0
# 8        pressure    NN  cause_consequence    sentence_id_0
# 9             the    DT            neutral    sentence_id_1
# 10         singer    NN  cause_consequence    sentence_id_1
# 11            who    WP            neutral    sentence_id_1
# 12      performed   VBD            neutral    sentence_id_1
# 13          three    CD            neutral    sentence_id_1
# 14             of    IN            neutral    sentence_id_1
# 15            the    DT            neutral    sentence_id_1
# 16      nominated    JJ  cause_consequence    sentence_id_1
# 17          songs   NNS  cause_consequence    sentence_id_1
# 18           also    RB            neutral    sentence_id_1
# 19         caused   VBD            neutral    sentence_id_1
# 20              a    DT            neutral    sentence_id_1
# 21      commotion    NN  cause_consequence    sentence_id_1
# 22             on    IN            neutral    sentence_id_1
# 23            the    DT            neutral    sentence_id_1
# 24            red    JJ  cause_consequence    sentence_id_1
# 25         carpet    NN  cause_consequence    sentence_id_1
# 26             he   PRP            neutral    sentence_id_2
# 27            had   VBD            neutral    sentence_id_2
# 28          chest    NN  cause_consequence    sentence_id_2
# 29          pains   NNS  cause_consequence    sentence_id_2
# ...           ...   ...                ...              ...
# 13004        crea    VB            neutral  sentence_id_735
# 13005     parents   NNS  cause_consequence  sentence_id_736
# 13006        also    RB            neutral  sentence_id_736
# 13007  experience   VBP            neutral  sentence_id_736
# 13008     anxiety    NN  cause_consequence  sentence_id_736
# 13009        from    IN            neutral  sentence_id_736
# 13010        fear    NN  cause_consequence  sentence_id_736
# 13011          of    IN            neutral  sentence_id_736
# 13012         the    DT            neutral  sentence_id_736
# 13013   suffering    NN  cause_consequence  sentence_id_736
# 13014          of    IN            neutral  sentence_id_736
# 13015       their  PRP$            neutral  sentence_id_736
# 13016       child    NN  cause_consequence  sentence_id_736
# 13017         and    CC            neutral  sentence_id_736
# 13018       worry    NN  cause_consequence  sentence_id_736
# 13019       about    IN            neutral  sentence_id_736
# 13020          an    DT            neutral  sentence_id_736
# 13021   uncertain    JJ  cause_consequence  sentence_id_736
# 13022     outcome    NN  cause_consequence  sentence_id_736
# 13023          in    IN            neutral  sentence_id_737
# 13024    chemical    NN  cause_consequence  sentence_id_737
# 13025      lasers   NNS  cause_consequence  sentence_id_737
# 13026         the    DT            neutral  sentence_id_737
# 13027   inversion    NN  cause_consequence  sentence_id_737
# 13028          is   VBZ            neutral  sentence_id_737
# 13029    produced   VBN            neutral  sentence_id_737
# 13030          by    IN            neutral  sentence_id_737
# 13031           a    DT            neutral  sentence_id_737
# 13032    chemical    NN  cause_consequence  sentence_id_737
# 13033    reaction    NN  cause_consequence  sentence_id_737
#
# [13034 rows x 4 columns]

# %%
nodes.to_excel('nodes.xlsx')

# %% [markdown]
# ### Edges

# %%
sentences_into_graph(text)
# Out:
#         from         to
# 0        the       fire
# 1       fire     inside
# 2     inside        wtc
# 3        wtc        was
# 4        was     caused
# 5     caused         by
# 6         by  exploding
# 7  exploding       fuel

# %%
from_word_total = []
to_word_total = []

for item in range(len(causeeffect)):
    try:
        from_word_total.append(sentences_into_graph(causeeffect['SENTENCES'].iloc[item])['from'].tolist())
        to_word_total.append(sentences_into_graph(causeeffect['SENTENCES'].iloc[item])['to'].tolist())
    except:
        print('No id')
        
id_sentence_v2 = []
for i in range(len(from_word_total)):
    id_sentence_v2.append(['sentence_id_'+str(i)]*(len(from_word_total[i])))

# %%
def flatten_list(nested_list):
    from functools import reduce
    result = reduce(lambda x,y: x+y,nested_list)
    return result

from_word_total = flatten_list(from_word_total)
to_word_total = flatten_list(to_word_total)
id_sentence_v2 = flatten_list(id_sentence_v2)

# %%
print("from_word_total:", len(from_word_total), "||","to_word_total:", len(to_word_total), "||","id_sentence_v2:", len(id_sentence_v2))
# Out:
# from_word_total: 12296 || to_word_total: 12296 || id_sentence_v2: 12296

# %%
edges = pd.DataFrame({'from':from_word_total, 'to': to_word_total, 'which_sentence':id_sentence_v2})

# %%
edges
# Out:
#              from          to   which_sentence
# 0             the       burst    sentence_id_0
# 1           burst         has    sentence_id_0
# 2             has        been    sentence_id_0
# 3            been      caused    sentence_id_0
# 4          caused          by    sentence_id_0
# 5              by       water    sentence_id_0
# 6           water      hammer    sentence_id_0
# 7          hammer    pressure    sentence_id_0
# 8             the      singer    sentence_id_1
# 9          singer         who    sentence_id_1
# 10            who   performed    sentence_id_1
# 11      performed       three    sentence_id_1
# 12          three          of    sentence_id_1
# 13             of         the    sentence_id_1
# 14            the   nominated    sentence_id_1
# 15      nominated       songs    sentence_id_1
# 16          songs        also    sentence_id_1
# 17           also      caused    sentence_id_1
# 18         caused           a    sentence_id_1
# 19              a   commotion    sentence_id_1
# 20      commotion          on    sentence_id_1
# 21             on         the    sentence_id_1
# 22            the         red    sentence_id_1
# 23            red      carpet    sentence_id_1
# 24             he         had    sentence_id_2
# 25            had       chest    sentence_id_2
# 26          chest       pains    sentence_id_2
# 27          pains         and    sentence_id_2
# 28            and   headaches    sentence_id_2
# 29      headaches        from    sentence_id_2
# ...           ...         ...              ...
# 12266       radio      signal  sentence_id_735
# 12267      signal          to  sentence_id_735
# 12268          to        crea  sentence_id_735
# 12269     parents        also  sentence_id_736
# 12270        also  experience  sentence_id_736
# 12271  experience     anxiety  sentence_id_736
# 12272     anxiety        from  sentence_id_736
# 12273        from        fear  sentence_id_736
# 12274        fear          of  sentence_id_736
# 12275          of         the  sentence_id_736
# 12276         the   suffering  sentence_id_736
# 12277   suffering          of  sentence_id_736
# 12278          of       their  sentence_id_736
# 12279       their       child  sentence_id_736
# 12280       child         and  sentence_id_736
# 12281         and       worry  sentence_id_736
# 12282       worry       about  sentence_id_736
# 12283       about          an  sentence_id_736
# 12284          an   uncertain  sentence_id_736
# 12285   uncertain     outcome  sentence_id_736
# 12286          in    chemical  sentence_id_737
# 12287    chemical      lasers  sentence_id_737
# 12288      lasers         the  sentence_id_737
# 12289         the   inversion  sentence_id_737
# 12290   inversion          is  sentence_id_737
# 12291          is    produced  sentence_id_737
# 12292    produced          by  sentence_id_737
# 12293          by           a  sentence_id_737
# 12294           a    chemical  sentence_id_737
# 12295    chemical    reaction  sentence_id_737
#
# [12296 rows x 3 columns]

# %%
edges.to_excel('edges.xlsx')
